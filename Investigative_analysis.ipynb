# %% [markdown]
# # What are the most common programming languages used in SaudiArabia??

# %% [markdown]
# A data analysis using Stackoverflow’s 2018 and 2019 Annual Developer Survey.

# %% [markdown]
# <img src='https://cdn.blog.psafe.com/en/blog/wp-content/uploads/2016/10/BLOG_EN_0510_Most-Useful-Coding-and-Programming-Languages-to-Know.jpg'></img>

# %% [markdown]
# ## Introduction

# %% [markdown]
# With the advent of new areas in Saudi Arabia such as Artificial Intelligence and Data Science, many programming languages that were poorly spoken and used are now experiencing a rise in popularity.

# %% [markdown]
# You may have already heard **“Python is the programming language of the moment”** or **“Functional Paradigm is much better than Object Oriented”**.

# %% [markdown]
# In this article, we are going to analyze real data to verify if these programming languages are really being used Saudi Arabia or if they are just rumors.

# %% [markdown]
# For this, we are going to use data from Stackoverflow’s 2018 and 2019 Annual Developer Survey.

# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSS1mvZ_iIRrWl08VZ-vxCwApQItiV7KX1RTrldjflujvWI2_cb-w'></img>

# %% [markdown]
# Every year, Stack Overflow conducts a massive survey of people on it’s website, covering all sorts of information like programming languages, jobs, code style and more.

# %% [markdown]
# There were more than 150 questions as a part of the survey, including:
#
# **“What frameworks do you work with?”** <br>
# **“Do you program as a hobby or contribute to open source projects?”** <br>
# **“What IDE do you work with?”** <br>

# %%
# to handle datasets
import numpy as np
import pandas as pd
from collections import Counter

# to visualise al the columns in the dataframe
pd.pandas.set_option('display.max_columns', None)

# to make plots
import matplotlib.pyplot as plt
import seaborn as sns

# to change plot style
sns.set(style="darkgrid")

# to ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Reading Stackoverflow survey data
df_2018 = pd.read_csv('data/2018/survey_results_public.csv')
df_2019 = pd.read_csv('data/2019/survey_results_public.csv')

# %%
# Sample 2018 Data
df_2018.head()
# Out:
#    Respondent Hobby OpenSource       Country Student          Employment  \
# 0        1648   Yes         No  Saudi Arabia      No  Employed full-time
# 1        2122   Yes         No  Saudi Arabia      No  Employed full-time
# 2        3299   Yes        Yes  Saudi Arabia      No  Employed full-time
# 3        3532   Yes         No  Saudi Arabia      No  Employed full-time
# 4        5436   Yes         No  Saudi Arabia      No  Employed full-time
#
#                                FormalEducation  \
# 0  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 1     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4     Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 0  Computer science, computer engineering, or sof...
# 1  Computer science, computer engineering, or sof...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0  10,000 or more employees
# 1        20 to 99 employees
# 2      100 to 499 employees
# 3        20 to 99 employees
# 4  10,000 or more employees
#
#                                              DevType  YearsCoding  \
# 0                               QA or test developer  12-14 years
# 1  Back-end developer;Designer;Front-end develope...    3-5 years
# 2            Back-end developer;Full-stack developer    6-8 years
# 3  Back-end developer;Data or business analyst;Da...    6-8 years
# 4  Back-end developer;Full-stack developer;QA or ...    6-8 years
#
#   YearsCodingProf          JobSatisfaction  \
# 0     15-17 years     Moderately satisfied
# 1       3-5 years       Slightly satisfied
# 2             NaN                      NaN
# 3       0-2 years    Slightly dissatisfied
# 4       3-5 years  Moderately dissatisfied
#
#                    CareerSatisfaction  \
# 0                Moderately satisfied
# 1                Moderately satisfied
# 2                                 NaN
# 3  Neither satisfied nor dissatisfied
# 4  Neither satisfied nor dissatisfied
#
#                                        HopeFiveYears  \
# 0  Working in a different or more specialized tec...
# 1  Working as a founder or co-founder of my own c...
# 2                                                NaN
# 3  Working in a different or more specialized tec...
# 4    Working as a product manager or project manager
#
#                                      JobSearchStatus  \
# 0  I’m not actively looking, but I am open to new...
# 1  I’m not actively looking, but I am open to new...
# 2                                                NaN
# 3                    I am actively looking for a job
# 4                    I am actively looking for a job
#
#                   LastNewJob  AssessJob1  AssessJob2  AssessJob3  AssessJob4  \
# 0       Less than a year ago         8.0        10.0         7.0         2.0
# 1  Between 2 and 4 years ago         3.0         2.0         7.0         4.0
# 2                        NaN         NaN         NaN         NaN         NaN
# 3  Between 2 and 4 years ago         8.0         1.0        10.0         2.0
# 4  Between 1 and 2 years ago         8.0         7.0         6.0         4.0
#
#    AssessJob5  AssessJob6  AssessJob7  AssessJob8  AssessJob9  AssessJob10  \
# 0         1.0         3.0         9.0         5.0         4.0          6.0
# 1         1.0         5.0         9.0         6.0        10.0          8.0
# 2         NaN         NaN         NaN         NaN         NaN          NaN
# 3         7.0         9.0         6.0         5.0         4.0          3.0
# 4         5.0         1.0        10.0         3.0         9.0          2.0
#
#    AssessBenefits1  AssessBenefits2  AssessBenefits3  AssessBenefits4  \
# 0              1.0              6.0             11.0              9.0
# 1              1.0             11.0              2.0              5.0
# 2              NaN              NaN              NaN              NaN
# 3              1.0              8.0              2.0             11.0
# 4              2.0              7.0             11.0             10.0
#
#    AssessBenefits5  AssessBenefits6  AssessBenefits7  AssessBenefits8  \
# 0              7.0             10.0              5.0              2.0
# 1              6.0             10.0              8.0              7.0
# 2              NaN              NaN              NaN              NaN
# 3              5.0              9.0              7.0              3.0
# 4              1.0              4.0              3.0              5.0
#
#    AssessBenefits9  AssessBenefits10  AssessBenefits11  JobContactPriorities1  \
# 0              8.0               3.0               4.0                    4.0
# 1              9.0               3.0               4.0                    3.0
# 2              NaN               NaN               NaN                    NaN
# 3             10.0               6.0               4.0                    1.0
# 4              9.0               8.0               6.0                    NaN
#
#    JobContactPriorities2  JobContactPriorities3  JobContactPriorities4  \
# 0                    1.0                    5.0                    3.0
# 1                    1.0                    5.0                    2.0
# 2                    NaN                    NaN                    NaN
# 3                    3.0                    4.0                    5.0
# 4                    NaN                    NaN                    NaN
#
#    JobContactPriorities5  JobEmailPriorities1  JobEmailPriorities2  \
# 0                    2.0                  1.0                  3.0
# 1                    4.0                  4.0                  5.0
# 2                    NaN                  NaN                  NaN
# 3                    2.0                  2.0                  4.0
# 4                    NaN                  6.0                  2.0
#
#    JobEmailPriorities3  JobEmailPriorities4  JobEmailPriorities5  \
# 0                  7.0                  2.0                  4.0
# 1                  2.0                  6.0                  3.0
# 2                  NaN                  NaN                  NaN
# 3                  7.0                  1.0                  5.0
# 4                  1.0                  5.0                  3.0
#
#    JobEmailPriorities6  JobEmailPriorities7  \
# 0                  6.0                  5.0
# 1                  1.0                  7.0
# 2                  NaN                  NaN
# 3                  3.0                  6.0
# 4                  4.0                  7.0
#
#                                             UpdateCV          Currency Salary  \
# 0  I did not receive an expected change in compen...               NaN    NaN
# 1     My job status or other personal status changed               NaN    NaN
# 2                                                NaN               NaN    NaN
# 3                           A recruiter contacted me  U.S. dollars ($)   3200
# 4           A friend told me about a job opportunity  U.S. dollars ($)    NaN
#
#   SalaryType  ConvertedSalary CurrencySymbol  \
# 0    Monthly              NaN            SAR
# 1    Monthly              NaN            SAR
# 2        NaN              NaN            NaN
# 3    Monthly          38400.0            USD
# 4        NaN              NaN            NaN
#
#                                   CommunicationTools  TimeFullyProductive  \
# 0  Confluence;Jira;Office / productivity suite (M...   Six to nine months
# 1  Office / productivity suite (Microsoft Office,...  One to three months
# 2                                                NaN                  NaN
# 3  Facebook;Office / productivity suite (Microsof...  One to three months
# 4  Office / productivity suite (Microsoft Office,...  One to three months
#
#                                       EducationTypes  \
# 0  Taught yourself a new language, framework, or ...
# 1  Taught yourself a new language, framework, or ...
# 2                                                NaN
# 3  Taken a part-time in-person course in programm...
# 4  Taken an online course in programming or softw...
#
#                                      SelfTaughtTypes TimeAfterBootcamp  \
# 0  The official documentation and/or standards fo...               NaN
# 1  The official documentation and/or standards fo...               NaN
# 2                                                NaN               NaN
# 3  The official documentation and/or standards fo...               NaN
# 4  The official documentation and/or standards fo...               NaN
#
#                                     HackathonReasons  AgreeDisagree1  \
# 0                                                NaN           Agree
# 1  To improve my general technical skills or prog...           Agree
# 2                                                NaN             NaN
# 3                                                NaN  Strongly agree
# 4  To improve my general technical skills or prog...           Agree
#
#                AgreeDisagree2              AgreeDisagree3  \
# 0  Neither Agree nor Disagree  Neither Agree nor Disagree
# 1                       Agree           Strongly disagree
# 2                         NaN                         NaN
# 3                    Disagree           Strongly disagree
# 4  Neither Agree nor Disagree  Neither Agree nor Disagree
#
#                                   LanguageWorkedWith  \
# 0  Groovy;Java;JavaScript;Perl;Python;SQL;HTML;CS...
# 1       C#;JavaScript;SQL;TypeScript;VB.NET;HTML;CSS
# 2                       Java;JavaScript;SQL;HTML;CSS
# 3  C++;C#;Java;JavaScript;Objective-C;SQL;TypeScr...
# 4  C;C++;C#;JavaScript;PHP;Python;SQL;HTML;CSS;Ba...
#
#                               LanguageDesireNextYear  \
# 0  Go;Groovy;Java;JavaScript;Perl;Python;SQL;Swif...
# 1  C#;Java;JavaScript;Python;SQL;TypeScript;HTML;CSS
# 2                                                NaN
# 3         C#;Java;JavaScript;SQL;TypeScript;HTML;CSS
# 4                  C++;C#;JavaScript;Python;Rust;SQL
#
#                      DatabaseWorkedWith  \
# 0                          MySQL;Oracle
# 1                      SQL Server;MySQL
# 2  SQL Server;MySQL;Oracle;Apache HBase
# 3        SQL Server;MySQL;SQLite;Oracle
# 4                      SQL Server;MySQL
#
#                               DatabaseDesireNextYear  \
# 0  MongoDB;Redis;SQL Server;MySQL;PostgreSQL;SQLi...
# 1                                  SQL Server;Oracle
# 2                                            MongoDB
# 3                                  SQL Server;SQLite
# 4                                   SQL Server;MySQL
#
#                                   PlatformWorkedWith  \
# 0                            Linux;Mac OS;SharePoint
# 1                                          WordPress
# 2                          Windows Desktop or Server
# 3  Android;Arduino;iOS;Windows Desktop or Server;...
# 4  Arduino;Mac OS;Windows Desktop or Server;WordP...
#
#                               PlatformDesireNextYear  \
# 0  Android;AWS;iOS;Linux;Mac OS;Raspberry Pi;Shar...
# 1                  Android;Azure;iOS;Linux;WordPress
# 2                                                AWS
# 3  Android;Arduino;iOS;Windows Desktop or Server;...
# 4                          Linux;Mac OS;Raspberry Pi
#
#                  FrameworkWorkedWith                FrameworkDesireNextYear  \
# 0                                NaN  Angular;Hadoop;Node.js;Xamarin;Spring
# 1                          .NET Core         .NET Core;Hadoop;Node.js;React
# 2                             Spring                        Angular;Node.js
# 3  Angular;.NET Core;Node.js;Xamarin      Angular;.NET Core;Node.js;Xamarin
# 4           Angular;.NET Core;Django     .NET Core;Node.js;React;TensorFlow
#
#                                                  IDE OperatingSystem  \
# 0           Eclipse;Notepad++;Vim;Visual Studio Code           MacOS
# 1                                      Visual Studio         Windows
# 2                                  Eclipse;Notepad++         Windows
# 3  Android Studio;Eclipse;Visual Studio;Visual St...         Windows
# 4  Atom;Sublime Text;Visual Studio;Visual Studio ...         Windows
#
#   NumberMonitors                                        Methodology  \
# 0              1                                        Agile;Scrum
# 1              1  Formal standard such as ISO 9001 or IEEE 12207...
# 2              1                                        Agile;Scrum
# 3              2                                              Scrum
# 4              1                                                NaN
#
#                                       VersionControl  \
# 0                                         Subversion
# 1                    Team Foundation Version Control
# 2                                         Subversion
# 3                Git;Team Foundation Version Control
# 4  Git;Team Foundation Version Control;Copying an...
#
#                 CheckInCode                  AdBlocker AdBlockerDisable  \
# 0  Less than once per month  I'm not sure/I don't know              NaN
# 1    Multiple times per day                         No              NaN
# 2    Multiple times per day                        Yes               No
# 3    Multiple times per day                        Yes              Yes
# 4                Once a day                        Yes              Yes
#
#                                     AdBlockerReasons  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  The website I was visiting forced me to disabl...
# 4  The website I was visiting asked me to disable...
#
#             AdsAgreeDisagree1           AdsAgreeDisagree2  \
# 0              Strongly agree              Strongly agree
# 1              Strongly agree           Somewhat disagree
# 2                         NaN                         NaN
# 3  Neither agree nor disagree  Neither agree nor disagree
# 4           Somewhat disagree           Somewhat disagree
#
#             AdsAgreeDisagree3  \
# 0  Neither agree nor disagree
# 1  Neither agree nor disagree
# 2                         NaN
# 3           Somewhat disagree
# 4              Strongly agree
#
#                                           AdsActions  AdsPriorities1  \
# 0  Saw an online advertisement and then researche...             7.0
# 1                                                NaN             1.0
# 2                                                NaN             NaN
# 3                                                NaN             4.0
# 4  Stopped going to a website because of their ad...             5.0
#
#    AdsPriorities2  AdsPriorities3  AdsPriorities4  AdsPriorities5  \
# 0             5.0             3.0             1.0             4.0
# 1             3.0             4.0             5.0             6.0
# 2             NaN             NaN             NaN             NaN
# 3             7.0             5.0             2.0             3.0
# 4             1.0             4.0             2.0             6.0
#
#    AdsPriorities6  AdsPriorities7  \
# 0             6.0             2.0
# 1             2.0             7.0
# 2             NaN             NaN
# 3             1.0             6.0
# 4             7.0             3.0
#
#                                          AIDangerous  \
# 0  Evolving definitions of "fairness" in algorith...
# 1  Artificial intelligence surpassing human intel...
# 2                                                NaN
# 3              Algorithms making important decisions
# 4  Evolving definitions of "fairness" in algorith...
#
#                                        AIInteresting  \
# 0                      Increasing automation of jobs
# 1              Algorithms making important decisions
# 2                                                NaN
# 3  Artificial intelligence surpassing human intel...
# 4              Algorithms making important decisions
#
#                              AIResponsible  \
# 0               Prominent industry leaders
# 1               Prominent industry leaders
# 2                                      NaN
# 3               Prominent industry leaders
# 4  A governmental or other regulatory body
#
#                                             AIFuture           EthicsChoice  \
# 0  I'm worried about the dangers more than I'm ex...                     No
# 1  I'm worried about the dangers more than I'm ex...                     No
# 2                                                NaN                    NaN
# 3  I'm excited about the possibilities more than ...                     No
# 4  I'm excited about the possibilities more than ...  Depends on what it is
#
#                        EthicsReport  \
# 0  Yes, but only within the company
# 1                 Yes, and publicly
# 2                               NaN
# 3  Yes, but only within the company
# 4             Depends on what it is
#
#                               EthicsResponsible    EthicalImplications  \
# 0  Upper management at the company/organization                    Yes
# 1          The person who came up with the idea                    Yes
# 2                                           NaN                    NaN
# 3                    The developer who wrote it                    Yes
# 4  Upper management at the company/organization  Unsure / I don't know
#
#   StackOverflowRecommend                   StackOverflowVisit  \
# 0       10 (Very Likely)  Less than once per month or monthly
# 1       10 (Very Likely)               Multiple times per day
# 2                    NaN                                  NaN
# 3                      6                 A few times per week
# 4       10 (Very Likely)                Daily or almost daily
#
#   StackOverflowHasAccount             StackOverflowParticipate  \
# 0                      No                                  NaN
# 1                     Yes                 A few times per week
# 2                     NaN                                  NaN
# 3                     Yes  Less than once per month or monthly
# 4                     Yes      A few times per month or weekly
#
#                                    StackOverflowJobs  \
# 0  No, I knew that Stack Overflow had a jobs boar...
# 1  No, I knew that Stack Overflow had a jobs boar...
# 2                                                NaN
# 3                                                Yes
# 4  No, I knew that Stack Overflow had a jobs boar...
#
#                StackOverflowDevStory StackOverflowJobsRecommend  \
# 0                                NaN                        NaN
# 1  No, and I don't know what that is                        NaN
# 2                                NaN                        NaN
# 3  No, and I don't know what that is                          5
# 4  No, and I don't know what that is                        NaN
#
#   StackOverflowConsiderMember       HypotheticalTools1  \
# 0                         Yes      Somewhat interested
# 1                         Yes    Not at all interested
# 2                         NaN                      NaN
# 3                         Yes      Somewhat interested
# 4                I'm not sure  A little bit interested
#
#         HypotheticalTools2       HypotheticalTools3    HypotheticalTools4  \
# 0          Very interested      Somewhat interested   Somewhat interested
# 1  A little bit interested  A little bit interested  Extremely interested
# 2                      NaN                      NaN                   NaN
# 3    Not at all interested      Somewhat interested   Somewhat interested
# 4      Somewhat interested      Somewhat interested   Somewhat interested
#
#      HypotheticalTools5                WakeTime HoursComputer  \
# 0   Somewhat interested  Between 5:00 - 6:00 AM   5 - 8 hours
# 1  Extremely interested  Between 5:00 - 6:00 AM  9 - 12 hours
# 2                   NaN                     NaN           NaN
# 3   Somewhat interested  Between 7:01 - 8:00 AM  9 - 12 hours
# 4   Somewhat interested  Between 7:01 - 8:00 AM  9 - 12 hours
#
#            HoursOutside                  SkipMeals  \
# 0           1 - 2 hours       1 - 2 times per week
# 1  Less than 30 minutes       3 - 4 times per week
# 2                   NaN                        NaN
# 3           1 - 2 hours       1 - 2 times per week
# 4       30 - 59 minutes  Daily or almost every day
#
#               ErgonomicDevices                    Exercise  Gender  \
# 0  Ergonomic keyboard or mouse  I don't typically exercise    Male
# 1  Fatigue-relieving floor mat  I don't typically exercise  Female
# 2                          NaN                         NaN     NaN
# 3                          NaN        3 - 4 times per week    Male
# 4                          NaN        3 - 4 times per week    Male
#
#           SexualOrientation                           EducationParents  \
# 0                       NaN  They never completed any formal education
# 1  Straight or heterosexual   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                       NaN                                        NaN
# 3  Straight or heterosexual  Other doctoral degree (Ph.D, Ed.D., etc.)
# 4  Straight or heterosexual  Other doctoral degree (Ph.D, Ed.D., etc.)
#
#                                  RaceEthnicity                Age Dependents  \
# 0                                          NaN  35 - 44 years old        Yes
# 1                               Middle Eastern  25 - 34 years old         No
# 2                                          NaN                NaN        NaN
# 3                               Middle Eastern  25 - 34 years old         No
# 4  Middle Eastern;White or of European descent  25 - 34 years old         No
#
#    MilitaryUS                         SurveyTooLong  \
# 0         NaN               The survey was too long
# 1         NaN               The survey was too long
# 2         NaN                                   NaN
# 3         NaN  The survey was an appropriate length
# 4         NaN  The survey was an appropriate length
#
#                    SurveyEasy
# 0               Somewhat easy
# 1               Somewhat easy
# 2                         NaN
# 3               Somewhat easy
# 4  Neither easy nor difficult

# %%
# Sample 2019 Data
df_2019.head()
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0         840  I am a student who is learning to code       No
# 1        1483  I am a student who is learning to code      Yes
# 2        1518          I am a developer by profession      Yes
# 3        1656          I am a developer by profession       No
# 4        2885  I am a student who is learning to code      Yes
#
#                   OpenSourcer  \
# 0  Once a month or more often
# 1                       Never
# 2                       Never
# 3                       Never
# 4                       Never
#
#                                           OpenSource  \
# 0  OSS is, on average, of LOWER quality than prop...
# 1  OSS is, on average, of HIGHER quality than pro...
# 2  OSS is, on average, of LOWER quality than prop...
# 3  OSS is, on average, of LOWER quality than prop...
# 4  OSS is, on average, of HIGHER quality than pro...
#
#                                Employment       Country         Student  \
# 0                      Employed full-time  Saudi Arabia  Yes, full-time
# 1      Not employed, but looking for work  Saudi Arabia  Yes, full-time
# 2                      Employed full-time  Saudi Arabia              No
# 3      Not employed, but looking for work  Saudi Arabia              No
# 4  Not employed, and not looking for work  Saudi Arabia              No
#
#                                              EdLevel  \
# 0                                                NaN
# 1  Secondary school (e.g. American high school, G...
# 2           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 0                                                NaN
# 1                                                NaN
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Information systems, information technology, o...
#
#                                             EduOther               OrgSize  \
# 0                                                NaN                   NaN
# 1  Taken an online course in programming or softw...                   NaN
# 2  Taken an online course in programming or softw...  500 to 999 employees
# 3  Taken an online course in programming or softw...                   NaN
# 4  Taken an online course in programming or softw...                   NaN
#
#                                              DevType           YearsCode  \
# 0                                                NaN  More than 50 years
# 1  Designer;Developer, desktop or enterprise appl...                   5
# 2  Developer, back-end;Developer, desktop or ente...                   7
# 3  Designer;Developer, full-stack;Developer, game...                   8
# 4                                                NaN    Less than 1 year
#
#       Age1stCode      YearsCodePro                           CareerSat  \
# 0  Older than 85               NaN                                 NaN
# 1             15               NaN                                 NaN
# 2             19                 4               Slightly dissatisfied
# 3             17  Less than 1 year  Neither satisfied nor dissatisfied
# 4             12               NaN                                 NaN
#
#                                JobSat            MgrIdiot MgrMoney MgrWant  \
# 0                                 NaN                 NaN      NaN     NaN
# 1                                 NaN                 NaN      NaN     NaN
# 2  Neither satisfied nor dissatisfied  Somewhat confident       No      No
# 3                                 NaN                 NaN      NaN     NaN
# 4                                 NaN                 NaN      NaN     NaN
#
#                                              JobSeek  \
# 0                    I am actively looking for a job
# 1  I’m not actively looking, but I am open to new...
# 2       I am not interested in new job opportunities
# 3                    I am actively looking for a job
# 4                                                NaN
#
#                                         LastHireDate  \
# 0  NA - I am an independent contractor or self em...
# 1  NA - I am an independent contractor or self em...
# 2                              More than 4 years ago
# 3                               I've never had a job
# 4                                                NaN
#
#                                              LastInt FizzBuzz  \
# 0                                                NaN      NaN
# 1                                                NaN      NaN
# 2  Interview with people in senior / management r...       No
# 3                                                NaN       No
# 4                                                NaN      NaN
#
#                                           JobFactors  \
# 0         Opportunities for professional development
# 1  Industry that I'd be working in;Opportunities ...
# 2  Languages, frameworks, and other technologies ...
# 3  Industry that I'd be working in;Specific depar...
# 4                                                NaN
#
#                                         ResumeUpdate CurrencySymbol  \
# 0                                                NaN            NaN
# 1  Something else changed (education, award, medi...            NaN
# 2                   I was preparing for a job search            SAR
# 3                   I was preparing for a job search            NaN
# 4                                                NaN            NaN
#
#           CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 0                  NaN        NaN      NaN            NaN          NaN
# 1                  NaN        NaN      NaN            NaN          NaN
# 2  Saudi Arabian riyal        NaN  Monthly            NaN         45.0
# 3                  NaN        NaN      NaN            NaN          NaN
# 4                  NaN        NaN      NaN            NaN          NaN
#
#                                             WorkPlan  \
# 0                                                NaN
# 1                                                NaN
# 2  There is a schedule and/or spec (made by me or...
# 3                                                NaN
# 4                                                NaN
#
#                                        WorkChallenge  \
# 0                                                NaN
# 1                                                NaN
# 2  Being tasked with non-development work;Distrac...
# 3                                                NaN
# 4                                                NaN
#
#                          WorkRemote WorkLoc   ImpSyn CodeRev  CodeRevHrs  \
# 0                               NaN     NaN      NaN     NaN         NaN
# 1                               NaN     NaN      NaN     NaN         NaN
# 2  Less than once per month / Never  Office  Average      No         NaN
# 3                               NaN     NaN      NaN     NaN         NaN
# 4                               NaN     NaN      NaN     NaN         NaN
#
#                    UnitTests PurchaseHow                   PurchaseWhat  \
# 0                        NaN         NaN                            NaN
# 1                        NaN         NaN                            NaN
# 2  No, but I think we should    Not sure  I have little or no influence
# 3                        NaN         NaN                            NaN
# 4                        NaN         NaN                            NaN
#
#                     LanguageWorkedWith           LanguageDesireNextYear  \
# 0                                  NaN                              NaN
# 1                        HTML/CSS;Java  HTML/CSS;Java;JavaScript;Python
# 2                               C#;SQL                              NaN
# 3          C#;HTML/CSS;Java;JavaScript                          C#;Dart
# 4  C#;HTML/CSS;Java;JavaScript;PHP;SQL                             Java
#
#      DatabaseWorkedWith        DatabaseDesireNextYear PlatformWorkedWith  \
# 0                   NaN                           NaN            Android
# 1   MySQL;Oracle;SQLite                           NaN            Windows
# 2  Microsoft SQL Server  MongoDB;Microsoft SQL Server            Windows
# 3              Firebase                      Firebase            Android
# 4          MySQL;SQLite                  MySQL;SQLite            Android
#
#   PlatformDesireNextYear  WebFrameWorkedWith WebFrameDesireNextYear  \
# 0                Android                 NaN                    NaN
# 1                Windows                 NaN                    NaN
# 2                Arduino      ASP.NET;jQuery                ASP.NET
# 3                Android  Angular/Angular.js     Angular/Angular.js
# 4                Android                 NaN                    NaN
#
#   MiscTechWorkedWith MiscTechDesireNextYear  \
# 0          Other(s):              Other(s):
# 1                NaN                    NaN
# 2               .NET              .NET Core
# 3           Unity 3D       Flutter;Unity 3D
# 4                NaN                    NaN
#
#                                    DevEnviron    OpSys  \
# 0                              Android Studio  Windows
# 1                            Eclipse;NetBeans  Windows
# 2            Visual Studio;Visual Studio Code  Windows
# 3  Android Studio;NetBeans;Visual Studio Code  Windows
# 4                              Android Studio  Windows
#
#                 Containers                                      BlockchainOrg  \
# 0                      NaN  Accepting Bitcoin or other coins and tokens as...
# 1  I do not use containers                                                NaN
# 2  I do not use containers                                                NaN
# 3  I do not use containers                                                NaN
# 4  I do not use containers                                                NaN
#
#                                         BlockchainIs BetterLife  ITperson  \
# 0                                                NaN        Yes  Also Yes
# 1  Useful for immutable record keeping outside of...         No      SIGH
# 2                                                NaN         No  Also Yes
# 3                                                NaN        Yes       Yes
# 4                                                NaN        Yes       Yes
#
#    OffOn SocialMedia              Extraversion ScreenName SOVisit1st  \
# 0    NaN         NaN                       NaN        NaN       2019
# 1    Yes     YouTube  In real life (in person)   Username       2013
# 2  What?      Reddit                   Neither   Username       2013
# 3    Yes    WhatsApp                   Neither      Login       2012
# 4  What?     YouTube                   Neither      Login       2017
#
#                        SOVisitFreq  \
# 0                              NaN
# 1             A few times per week
# 2            Daily or almost daily
# 3  A few times per month or weekly
# 4           Multiple times per day
#
#                                            SOVisitTo             SOFindAnswer  \
# 0                                                NaN                      NaN
# 1  Find answers to specific questions;Get a sense...       1-2 times per week
# 2                 Find answers to specific questions      6-10 times per week
# 3                 Find answers to specific questions       3-5 times per week
# 4  Find answers to specific questions;Learn how t...  Less than once per week
#
#                       SOTimeSaved  SOHowMuchTime                  SOAccount  \
# 0                             NaN            NaN                        NaN
# 1        They were about the same            NaN                        Yes
# 2  Stack Overflow was much faster  11-30 minutes  Not sure / can't remember
# 3        They were about the same            NaN                        Yes
# 4        They were about the same            NaN                        Yes
#
#                                           SOPartFreq  \
# 0                                                NaN
# 1  I have never participated in Q&A on Stack Over...
# 2                                                NaN
# 3  I have never participated in Q&A on Stack Over...
# 4  I have never participated in Q&A on Stack Over...
#
#                                               SOJobs  \
# 0                                                NaN
# 1  No, I knew that Stack Overflow had a job board...
# 2  No, I didn't know that Stack Overflow had a jo...
# 3  No, I didn't know that Stack Overflow had a jo...
# 4  No, I didn't know that Stack Overflow had a jo...
#
#                               EntTeams          SOComm  \
# 0                                  NaN             NaN
# 1  No, and I don't know what those are         Neutral
# 2  No, and I don't know what those are  No, not really
# 3  No, and I don't know what those are  No, not really
# 4  No, and I don't know what those are        Not sure
#
#                               WelcomeChange  \
# 0                                       NaN
# 1  Somewhat more welcome now than last year
# 2   Just as welcome now as I felt last year
# 3   Just as welcome now as I felt last year
# 4  Somewhat more welcome now than last year
#
#                                         SONewContent   Age Gender Trans  \
# 0                                                NaN   NaN    NaN   NaN
# 1  Industry news about technologies you're intere...  20.0  Woman    No
# 2  Tech articles written by other developers;Cour...  30.0    Man    No
# 3                                                NaN  25.0    Man    No
# 4  Tech articles written by other developers;Cour...  24.0    Man    No
#
#                  Sexuality       Ethnicity Dependents           SurveyLength  \
# 0                      NaN             NaN        Yes                    NaN
# 1                      NaN  Middle Eastern         No               Too long
# 2  Straight / Heterosexual  Middle Eastern        Yes               Too long
# 3                 Bisexual  Middle Eastern         No               Too long
# 4                      NaN             NaN         No  Appropriate in length
#
#                    SurveyEase
# 0                         NaN
# 1                        Easy
# 2  Neither easy nor difficult
# 3  Neither easy nor difficult
# 4  Neither easy nor difficult

# %% [markdown]
# ## 1. What programming languages are most used to work and which programming languages are most required?

# %%
def filter_country(df, column_filter, country, columns):
    ''' Filter a dataframe by country.,
        returns filtred dataframe.
    '''
    
    df_copy = df
    
    for column in columns: 
        df_copy = df_copy[df_copy[column_filter] == country].dropna(subset=[column])
        
    return df_copy

# Filter the dataframe by SaudiArabia and selecting some columns.
SaudiArabia_2018 = filter_country(df_2018, 'Country', 'Saudi Arabia', ['LanguageWorkedWith', 'LanguageDesireNextYear'])
SaudiArabia_2019 = filter_country(df_2019, 'Country', 'Saudi Arabia', ['LanguageWorkedWith', 'LanguageDesireNextYear'])

# %%
def split_column(df, column):
    ''' Split column by ;,
        returns a splited series.
    '''
    
    df_copy = df
    column_series = df_copy[column].apply(lambda x: x.split(';'))
    
    return column_series

# Splitting the Data Frame by column into a Series. 
worked_lang_2018 = split_column(SaudiArabia_2018, 'LanguageWorkedWith')
wanted_lang_2018 = split_column(SaudiArabia_2018, 'LanguageDesireNextYear')

worked_lang_2019 = split_column(SaudiArabia_2019, 'LanguageWorkedWith')
wanted_lang_2019 = split_column(SaudiArabia_2019, 'LanguageDesireNextYear')

# %%
def disarray(array_list):
    ''' Flat a nested list,
        returns a flat list.
    '''
    
    objects = []
    
    for row in array_list:
        for obj in row:
            objects.append(obj.strip())
            
    return objects

# Flatting nested list objects.
list_worked_languages_2018 = disarray(worked_lang_2018)
list_wanted_languages_2018 = disarray(wanted_lang_2018)

list_worked_languages_2019 = disarray(worked_lang_2019)
list_wanted_languages_2019 = disarray(wanted_lang_2019)

# %%
def group_list(data_list, year):
    ''' Group by count to a list,
        returns a result dict.
    '''
    
    grouped_list = dict(Counter(data_list))
    grouped_dict = [{'Programming Language':key, 'Count': value, 'Year': year} for key, value in grouped_list.items()]
    
    return grouped_dict

# Groping a list and creating a dict.
dict_worked_languages_2018 = group_list(list_worked_languages_2018, '2018')
dict_wanted_languages_2018 = group_list(list_wanted_languages_2018, '2018')

dict_worked_languages_2019 = group_list(list_worked_languages_2019, '2019')
dict_wanted_languages_2019 = group_list(list_wanted_languages_2019, '2019')

# %%
def create_dataframe(data_dicts):
    ''' Create two dataframes and append them,
        returns a appended dataframe.
    '''
        
    df1 = pd.DataFrame(data_dicts[0])
    df2 = pd.DataFrame(data_dicts[1])

    df = df1.append(df2)
    
    return df

# Creating a Data Frame appending the data.
worked_languages = create_dataframe([dict_worked_languages_2018, dict_worked_languages_2019])
wanted_languages = create_dataframe([dict_wanted_languages_2018, dict_wanted_languages_2019])

# %%
def percentage(df, column):
    ''' Scale data,
        returns data scaled.
    '''
    
    df_copy = df
    series = []
    
    for val in df_copy[column].unique():
        series.append(df_copy[df_copy[column] == val]['Count'] / 
                      df_copy[df_copy[column] == val]['Count'].sum())
    
    joined_series = pd.Series()
    for i_series in series:
        joined_series = joined_series.append(i_series)
        
    return joined_series

# Calculating the percentage
worked_languages['Percentage'] = percentage(worked_languages, 'Year')
wanted_languages['Percentage'] = percentage(wanted_languages, 'Year')

# %%
# Get the top 10 languages
top_10_worked_lang = worked_languages.sort_values(by=['Percentage'], ascending=False).head(10)['Programming Language'].unique()
top_10_wanted_lang = wanted_languages.sort_values(by=['Percentage'], ascending=False).head(10)['Programming Language'].unique()

worked_lang_chart = worked_languages[worked_languages['Programming Language'].isin(top_10_worked_lang)]
wanted_lang_chart = wanted_languages[wanted_languages['Programming Language'].isin(top_10_worked_lang)]

# %% [markdown]
# We can see that classic languages like: **HTML**, **CSS**, **Java Script** and **SQL** are still in the top positions. Stack Overflow 2018 survey data and Stack Overflow 2019 survey data

# %% [markdown]
# also, that in 2019 **SQL** significantly increased probably happened due to the focusing and interest of  in data related areas such as Business Intelligence and Big Data in Saudi Arabia.

# %%
# Figure 1 — Percentage of use of programming languages among all the cited programming 
# languages by the respondents.

plt.figure(figsize=(14,8))
sns.barplot(x = 'Percentage', 
            y = 'Programming Language',
            hue = 'Year',
            data = worked_lang_chart.sort_values(by='Percentage', ascending=False))

plt.xlabel("Percentage", fontsize = 14)
plt.ylabel("Programming Languages", fontsize = 14)
plt.legend(fontsize='x-large')
plt.title('Most common Programming Languages used in SaudiArabia', size = 16)
plt.show()

# %% [markdown]
# ## Part 2 — What are the most wanted programming languages in Saudi Arabia?

# %% [markdown]
# Most of the programming languages that have appeared as programming languages most used at work, also appeared in the ranking of most wanted programming languages, this show us that are many people wanting to learn these languages.

# %%
# Figure 2 — Percentage of desire of programming languages among all the cited programming 
# languages by the respondents.

plt.figure(figsize=(14,8))
sns.barplot(x = 'Percentage', 
            y = 'Programming Language',
            hue = 'Year',
            data = wanted_lang_chart.sort_values(by='Percentage', ascending=False))

plt.title('Most wanted Programming Languages used in SaudiArabia', size = 16)
plt.xlabel("Percentage", fontsize = 14)
plt.ylabel("Programming Languages", fontsize = 14)
plt.legend(fontsize='x-large')
plt.show()

# %% [markdown]
# ## Part 3 —How does programming languages used at work relates with programming languages people want to learn?

# %% [markdown]
# By looking at the raw data, we can spot some patterns such as for people that use SQL at work, for example, python is also cited as language that those people wanted to learn in the next year.

# %% [markdown]
# A natural question arise:
#
# **“The pattern observed for SQL holds for the other languages?”**

# %% [markdown]
# To address this question, we built a heat map that indicate how the work programming languages ​​were related to the desired programming languages. The darker the position gets, the more related the programming language is.

# %%
# Grouping data to create a new dataframe

rows = []
for itens in list(zip(worked_lang_2019, wanted_lang_2019)):
    for i in itens[0]:
        rows.append({
            'Worked_PL': i, 
            'Wanted_PL': Counter(itens[0])
        })
        
programming_language_transition = pd.DataFrame(rows).groupby('Worked_PL').agg({'Wanted_PL': 'sum'}).reset_index()

# %%
# Creating a matrix

for row in programming_language_transition['Worked_PL']:
    programming_language_transition[row] = 0

for index, row in programming_language_transition.iterrows():
    total = sum([value for key, value in dict(row['Wanted_PL']).items()])
    for key, value in dict(row['Wanted_PL']).items():
         programming_language_transition[key].loc[index] = (value / total)

# %%
## Figure 3 — Percentage of relationship of work programming languages and desire programming 
## languages in 2018 and 2019.

matrix = programming_language_transition.drop('Wanted_PL', axis=1)\
                                        .set_index('Worked_PL')

plt.figure(figsize=(16, 10))
sns.heatmap(matrix, cmap="YlGnBu")
plt.title('Programming Languages Heatmap', size = 16)
plt.ylabel('')
plt.show()

# %% [markdown]
# With this figure we can have two insights:
#
# 1. As is evidenced by the diagonal line, people who already work with a programming language have a strong probability of wanting to learn the same programming language.
#
# 2. People who work with a programming language of a specific area, tend to want to learn programming languages of the same area. For example: **HTML** is strongly correlated with **CSS** , **JavaScript** and **SQL**.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this article, we took a look at what were the most popular and most biased programming languages, according to Stackoverflow’s 2018 and 2019 Annual Developer Survey data.
#
# 1. We have seen that some older programming languages such as **JavaScript**, **SQL**, and **Java** still dominates.
# 2. world trend jobs and skills affect to increase the demand on **SQL**.
# 3. People who already work with a certain programming language have a tendency to learn that language or related languages within correlated areas to improve their own skill.
#
# To see more about this analysis, see the link to my medium post available [here](https://medium.com/@awesome_india_bear_819/what-are-the-most-common-programming-languages-used-in-saudi-arabia-c2fca6c1cafb).

# %% [markdown]
# ## References

# %% [markdown]
# Stackoverflow Developer Survey Data: [https://insights.stackoverflow.com/survey](https://insights.stackoverflow.com/survey) <br>
# Medium: [https://medium.com/@awesome_india_bear_819/what-are-the-most-common-programming-languages-used-in-saudi-arabia-c2fca6c1cafb](https://medium.com/@awesome_india_bear_819/what-are-the-most-common-programming-languages-used-in-saudi-arabia-c2fca6c1cafb)
